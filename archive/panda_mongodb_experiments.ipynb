# %%
currenttime = pd.Timestamp.now()
currenttime

days10Ago = pd.Timestamp.now() - pd.Timedelta(days=2)
days10Ago

# 1 hour from now:
hours1fromNow = pd.Timestamp.now() + pd.Timedelta(hours=1)
hours1fromNow

# if (hours1fromNow.to_pydatetime() - currenttime.to_pydatetime()) / 60 > 60:
#     print()
print(  (hours1fromNow.to_pydatetime() - pd.Timestamp.now().to_pydatetime()).seconds / 60 )

# {'uv': 0.05, 'humidity': 64.0, 'temperature': 25.1, 
#  'timestamp': Timestamp('2023-04-02 18:09:47.463036'), 
#  'apparentTemperature': 51.07654545454545}
# 
#  
client = MongoClient('mongodb+srv://user2:password123$$$@cluster0.wz9ds7q.mongodb.net/?retryWrites=true&w=majority', 27017)

db = client.flask_db
todos = db.todos4

x = todos.find()
# data_pd = {}
# for data in x:
#     print(data)
# 
# # import time.sleep()

def insertdata(data):
    #  uncomment this once ready to insert into mongodb:
    
    x = todos.insert_one(data)
    x = str(x.inserted_id)
    print(f"id generated for inserted data: {x}")

# insertdata({"hello": "helloo"})
# 
# # https://www.techiedelight.com/generate-random-float-python/
# https://pynative.com/python-random-choice/

counter = 0
import random

def insertdata(data):
    #  uncomment this once ready to insert into mongodb:
    x = todos.insert_one(data)
    x = str(x.inserted_id)
    print(f"id generated for inserted data: {x}")


compiledData = []
highRanges = random.choice([0,1])
lapsed30min = False

counter = 0

while days10Ago.to_pydatetime() < hours1fromNow.to_pydatetime():
    # what is the precision for each sensor like 
    #     -- can tell during dmeonstration - if incremental by only 0.02 then 
    #           need to generate a list and choose from list using random.choice(list)
    # what is the min max can control here:



    timer = pd.Timedelta(minutes=0)
    while lapsed30min == False:
        uv_rand = round(random.uniform(9.00, 11.00), 2)
        humidity_rand = round(random.uniform(63.00, 66.00))
        temp_rand = round(random.uniform(29.00, 34.00), 2)
        timer += pd.Timedelta(minutes=1)

        days10Ago += pd.Timedelta(minutes=1)
        generated_data = {
        "uv":uv_rand,
        "humidity": humidity_rand,
        "temperature": temp_rand,
            "timestamp": days10Ago
        }
        # print(generated_data)
        # insertdata(generated_data)
        # print("printing high range")
        compiledData.append(generated_data)
        if timer >= pd.Timedelta(minutes=30):
            lapsed30min = True

    if highRanges == 0:
        # run the low ranges for 10 min:
        timer2 = pd.Timedelta(minutes=0)
        while timer2 <= pd.Timedelta(minutes=10):
            timer2 += pd.Timedelta(minutes=1)
            uv_rand = round(random.uniform(0.006, 0.009), 2)
            humidity_rand = round(random.uniform(58.00, 62.00))
            temp_rand = round(random.uniform(25.00, 29.00), 2)

            days10Ago += pd.Timedelta(minutes=1)
            generated_data = {
            "uv":uv_rand,
            "humidity": humidity_rand,
            "temperature": temp_rand,
                "timestamp": days10Ago
            }
            compiledData.append(generated_data)
            # insertdata(generated_data)
            # print("printing low range")

    highRanges = random.choice([0,1])
    print(highRanges)
    lapsed30min = False if highRanges == 0 else True

    # if counter > 10:
    #     break
    # counter += 1



    # days10Ago += pd.Timedelta(minutes=1)
    # generated_data = {
    #    "uv":uv_rand,
    #    "humidity": humidity_rand,
    #    "temperature": temp_rand,
    #     "timestamp": days10Ago
    # }
    # print(generated_data)
    # uncomment this once ready to insert into mongodb:
    # x = todos.insert_one(generated_data)
    # x = str(x.inserted_id)
    # print(f"id generated for inserted data: {x}")
    # counter += 1
    # if counter > 10:
    #     break

# %%
# x = todos.insert_many(compiledData)

# %%
# print(len(x.inserted_ids))
# print(x.inserted_ids)
